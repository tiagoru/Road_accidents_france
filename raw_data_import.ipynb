# %%
import glob
import pandas as pd
import numpy as np

# %%
# read user files in data directory
files = []
for file in glob.glob("../mar23cds_accidents_data_import/usagers*.csv"):
    files.append(file)

# import user files
users = pd.DataFrame()

for i in range(0, len(files)):
    file = pd.read_csv(files[i], sep = ',')
    if i == 0:
        users = file
    else:
        users = pd.concat([users, file], axis = 0)

# export csv
users.to_csv("./data/users.csv", sep = ',', header = True, na_rep = 'n/a', index=False)
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2509620 entries, 0 to 197497
# Data columns (total 16 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Num_Acc      int64
#  1   id_vehicule  object
#  2   num_veh      object
#  3   place        float64
#  4   catu         int64
#  5   grav         int64
#  6   sexe         int64
#  7   an_nais      float64
#  8   trajet       float64
#  9   secu1        float64
#  10  secu2        float64
#  11  secu3        float64
#  12  locp         float64
#  13  actp         object
#  14  etatp        float64
#  15  secu         float64
# dtypes: float64(9), int64(4), object(3)
# memory usage: 325.5+ MB

# %%
users.head()
# Out:
#         Num_Acc  id_vehicule num_veh  place  catu  grav  sexe  an_nais  \
# 0  201900000001  138 306 524     B01    2.0     2     4     2   2002.0
# 1  201900000001  138 306 524     B01    1.0     1     4     2   1993.0
# 2  201900000001  138 306 525     A01    1.0     1     1     1   1959.0
# 3  201900000002  138 306 523     A01    1.0     1     4     2   1994.0
# 4  201900000003  138 306 520     A01    1.0     1     1     1   1996.0
#
#    trajet  secu1  secu2  secu3  locp actp  etatp  secu
# 0     0.0    1.0    0.0   -1.0  -1.0   -1   -1.0   NaN
# 1     5.0    1.0    0.0   -1.0  -1.0   -1   -1.0   NaN
# 2     0.0    1.0    0.0   -1.0  -1.0   -1   -1.0   NaN
# 3     0.0    1.0    0.0   -1.0  -1.0   -1   -1.0   NaN
# 4     0.0    1.0    0.0   -1.0  -1.0    0   -1.0   NaN

# %%
# read characteristics (=features) files in data directory
files = []
for file in glob.glob("../mar23cds_accidents_data_import/caracter*.csv"):
    files.append(file)

# import user files
features = pd.DataFrame()

for i in range(0, len(files)):
    file = pd.read_csv(files[i], sep = ',', encoding='latin-1', na_values=['N/A', 'n/a',''])
    if i == 0:
        features = file
    else:
        features = pd.concat([features, file], axis = 0)

# export csv
features.to_csv("./data/features.csv", sep = ',', header = True, na_rep = 'n/a', index=False)
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 982060 entries, 0 to 58396
# Data columns (total 16 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Num_Acc  982060 non-null  int64
#  1   an       982060 non-null  int64
#  2   mois     982060 non-null  int64
#  3   jour     982060 non-null  int64
#  4   hrmn     982060 non-null  object
#  5   lum      982060 non-null  int64
#  6   agg      982060 non-null  int64
#  7   int      982060 non-null  int64
#  8   atm      981987 non-null  float64
#  9   col      982041 non-null  float64
#  10  com      982058 non-null  object
#  11  adr      850489 non-null  object
#  12  gps      455722 non-null  object
#  13  lat      553725 non-null  object
#  14  long     553721 non-null  object
#  15  dep      982060 non-null  object
# dtypes: float64(2), int64(7), object(7)
# memory usage: 127.4+ MB

# %%
# read places files in data directory
files = []
for file in glob.glob("../mar23cds_accidents_data_import/lieux*.csv"):
    files.append(file)

# import user files
places = pd.DataFrame()

for i in range(0, len(files)):
    file = pd.read_csv(files[i], sep = ',', encoding='latin-1', na_values=['N/A', 'n/a',''], low_memory=False)
    if i == 0:
        places = file
    else:
        places = pd.concat([features, file], axis = 0)

# export csv
places.to_csv("./data/places.csv", sep = ',', header = True, na_rep = 'N/A', index=False)
places.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1069086 entries, 0 to 87025
# Data columns (total 33 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   Num_Acc  1069086 non-null  int64
#  1   an       982060 non-null   float64
#  2   mois     982060 non-null   float64
#  3   jour     982060 non-null   float64
#  4   hrmn     982060 non-null   object
#  5   lum      982060 non-null   float64
#  6   agg      982060 non-null   float64
#  7   int      982060 non-null   float64
#  8   atm      981987 non-null   float64
#  9   col      982041 non-null   float64
#  10  com      982058 non-null   object
#  11  adr      850489 non-null   object
#  12  gps      455722 non-null   object
#  13  lat      553725 non-null   object
#  14  long     553721 non-null   object
#  15  dep      982060 non-null   object
#  16  catr     87025 non-null    float64
#  17  voie     79497 non-null    float64
#  18  v1       86821 non-null    float64
#  19  v2       2136 non-null     object
#  20  circ     87026 non-null    float64
#  21  nbv      87026 non-null    float64
#  22  pr       47515 non-null    float64
#  23  pr1      47515 non-null    float64
#  24  vosp     87026 non-null    float64
#  25  prof     87026 non-null    float64
#  26  plan     87026 non-null    float64
#  27  lartpc   87026 non-null    float64
#  28  larrout  87026 non-null    float64
#  29  surf     87026 non-null    float64
#  30  infra    87026 non-null    float64
#  31  situ     87026 non-null    float64
#  32  env1     87026 non-null    float64
# dtypes: float64(24), int64(1), object(8)
# memory usage: 277.3+ MB

# %%
# read vehicle files in data directory
files = []
for file in glob.glob("../mar23cds_accidents_data_import/vehicules*.csv"):
    files.append(file)

# import user files
vehicles = pd.DataFrame()

for i in range(0, len(files)):
    file = pd.read_csv(files[i], sep = ',', encoding='latin-1', na_values=['N/A', 'n/a',''], low_memory=False)
    if i == 0:
        vehicles = file
    else:
        vehicles = pd.concat([vehicles, file], axis = 0)

# export csv
vehicles.to_csv("./data/vehicles.csv", sep = ',', header = True, na_rep = 'N/A', index=False)
vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1914902 entries, 0 to 131047
# Data columns (total 11 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Num_Acc      int64
#  1   senc         float64
#  2   catv         int64
#  3   occutc       float64
#  4   obs          float64
#  5   obsm         float64
#  6   choc         float64
#  7   manv         float64
#  8   num_veh      object
#  9   id_vehicule  object
#  10  motor        float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 175.3+ MB

# %%
vehicles.head()
# Out:
#         Num_Acc  senc  catv  occutc  obs  obsm  choc  manv num_veh  \
# 0  200500000001   0.0     7     0.0  0.0   2.0   1.0   1.0     A01
# 1  200500000001   0.0     7     0.0  0.0   2.0   8.0  10.0     B02
# 2  200500000002   0.0     7     0.0  0.0   2.0   7.0  16.0     A01
# 3  200500000002   0.0     2     0.0  0.0   2.0   1.0   1.0     B02
# 4  200500000003   0.0     2     0.0  0.0   2.0   1.0   1.0     A01
#
#   id_vehicule  motor
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN
# 3         NaN    NaN
# 4         NaN    NaN

# %%
# read registered vehicle files in data directory
files = []
for file in glob.glob("../mar23cds_accidents_data_import/registered_vehicles*.csv"):
    files.append(file)

# import user files
registered_vehicles = pd.DataFrame()

for i in range(0, len(files)):
    file = pd.read_csv(files[i], sep = ';', na_values=['N/A', 'n/a',''], low_memory=False, encoding="UTF-8")
    if i == 0:
        registered_vehicles = file
    else:
        registered_vehicles = pd.concat([registered_vehicles, file], axis = 0)

registered_vehicles.head()
# Out:
#   Id_accident Lettre Conventionnelle Véhicule  Année  \
# 0     900 493                               A   2014
# 1     900 493                               B   2014
# 2     900 494                               A   2014
# 3     900 495                               A   2014
# 4     900 496                               A   2014
#
#   Lieu Admin Actuel - Territoire Nom    Type Accident - Libellé  \
# 0                                DOM             Accident Léger
# 1                                DOM             Accident Léger
# 2                                DOM  Accident grave non mortel
# 3                                DOM  Accident grave non mortel
# 4                                DOM  Accident grave non mortel
#
#               CNIT Catégorie véhicule Age véhicule  \
# 0  VF7MFDJYF651296                 VT          NaN
# 1              NaN              Cyclo          NaN
# 2              NaN                 VT          4.0
# 3     LMP21C10N026              Cyclo          7.0
# 4     LSY91C10U174              Cyclo          6.0
#
#   Type Accident - Libellé (old)
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN

# %%
registered_vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200791 entries, 0 to 74663
# Data columns (total 9 columns):
#  #   Column                              Non-Null Count    Dtype
# ---  ------                              --------------    -----
#  0   Id_accident                         1200791 non-null  object
#  1   Lettre Conventionnelle Véhicule     1200790 non-null  object
#  2   Année                               1200791 non-null  int64
#  3   Lieu Admin Actuel - Territoire Nom  1200791 non-null  object
#  4   Type Accident - Libellé             1078193 non-null  object
#  5   CNIT                                776011 non-null   object
#  6   Catégorie véhicule                  1200791 non-null  object
#  7   Age véhicule                        1096605 non-null  object
#  8   Type Accident - Libellé (old)       122598 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 91.6+ MB

# %%
# data wrangling
# Id_accident contains whitespace, needs to be removed

registered_vehicles['Id_accident'] = registered_vehicles['Id_accident'].replace(" ", "")

# %%
registered_vehicles['Id_accident']
# Out:
# 0           900 493
# 1           900 493
# 2           900 494
# 3           900 495
# 4           900 496
#             ...
# 74659    66 554 980
# 74660    66 554 980
# 74661    66 554 981
# 74662    66 554 982
# 74663    66 554 982
# Name: Id_accident, Length: 1200791, dtype: object

# %%
# The whitespace is not removed. Very strange.
# Let's check the string:
registered_vehicles.iloc[0].Id_accident
# Out:
# '900\xa0493'

# %%
registered_vehicles.iloc[74659].Id_accident
# Out:
# '946\xa0769'

# %%
# well, this is unbreakable space...
# strange encoding..
# found this https://stackoverflow.com/questions/10993612/how-to-remove-xa0-from-string-in-python

# %%
new_id = list()
for i in range(0, len(registered_vehicles)):
    new_id.append(registered_vehicles.iloc[i].Id_accident.replace('\xa0', ''))

# %%
# Replace
registered_vehicles.Id_accident = new_id

# new_id is still string, so let's change:
registered_vehicles = registered_vehicles.astype({"Id_accident":"int"})

# %%
vehicles.head()
# Out:
#         Num_Acc  senc  catv  occutc  obs  obsm  choc  manv num_veh  \
# 0  200500000001   0.0     7     0.0  0.0   2.0   1.0   1.0     A01
# 1  200500000001   0.0     7     0.0  0.0   2.0   8.0  10.0     B02
# 2  200500000002   0.0     7     0.0  0.0   2.0   7.0  16.0     A01
# 3  200500000002   0.0     2     0.0  0.0   2.0   1.0   1.0     B02
# 4  200500000003   0.0     2     0.0  0.0   2.0   1.0   1.0     A01
#
#   id_vehicule  motor
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN
# 3         NaN    NaN
# 4         NaN    NaN

# %%
registered_vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200791 entries, 0 to 74663
# Data columns (total 9 columns):
#  #   Column                              Non-Null Count    Dtype
# ---  ------                              --------------    -----
#  0   Id_accident                         1200791 non-null  int64
#  1   Lettre Conventionnelle Véhicule     1200790 non-null  object
#  2   Année                               1200791 non-null  int64
#  3   Lieu Admin Actuel - Territoire Nom  1200791 non-null  object
#  4   Type Accident - Libellé             1078193 non-null  object
#  5   CNIT                                776011 non-null   object
#  6   Catégorie véhicule                  1200791 non-null  object
#  7   Age véhicule                        1096605 non-null  object
#  8   Type Accident - Libellé (old)       122598 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 91.6+ MB

# %%
# export csv
registered_vehicles.to_csv("./data/registered_vehicles.csv", sep = ',', header = True, na_rep = 'N/A', index=False)

# %% [markdown]
# ## Update 11 June 2023
# I realised that users has a similar field, I just convert this additionally1

# %%
users.iloc[0].id_vehicule
# Out:
# '138\xa0306\xa0524'

# %%
users.head()
# Out:
#         Num_Acc  id_vehicule num_veh  place  catu  grav  sexe  an_nais  \
# 0  201900000001  138 306 524     B01    2.0     2     4     2   2002.0
# 1  201900000001  138 306 524     B01    1.0     1     4     2   1993.0
# 2  201900000001  138 306 525     A01    1.0     1     1     1   1959.0
# 3  201900000002  138 306 523     A01    1.0     1     4     2   1994.0
# 4  201900000003  138 306 520     A01    1.0     1     1     1   1996.0
#
#    trajet  secu1  secu2  secu3  locp actp  etatp  secu
# 0     0.0    1.0    0.0   -1.0  -1.0   -1   -1.0   NaN
# 1     5.0    1.0    0.0   -1.0  -1.0   -1   -1.0   NaN
# 2     0.0    1.0    0.0   -1.0  -1.0   -1   -1.0   NaN
# 3     0.0    1.0    0.0   -1.0  -1.0   -1   -1.0   NaN
# 4     0.0    1.0    0.0   -1.0  -1.0    0   -1.0   NaN

# %% [markdown]
# So, same procedure as above:

# %%
# In the column exist nas, so a little different processing
new_id_users = list()
for i in range(0, len(users)):
    if type(users.iloc[i].id_vehicule) == str:
        new_id_users.append(users.iloc[i].id_vehicule.replace('\xa0', ''))
    elif np.isnan(users.iloc[i].id_vehicule) == True:
        new_id_users.append(pd.NA)

# %%
# Replace
users.id_vehicule = new_id_users

# new_id is still string, so let's change:
users.id_vehicule = users['id_vehicule'].astype('Int64')
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2509620 entries, 0 to 197497
# Data columns (total 16 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Num_Acc      int64
#  1   id_vehicule  Int64
#  2   num_veh      object
#  3   place        float64
#  4   catu         int64
#  5   grav         int64
#  6   sexe         int64
#  7   an_nais      float64
#  8   trajet       float64
#  9   secu1        float64
#  10  secu2        float64
#  11  secu3        float64
#  12  locp         float64
#  13  actp         object
#  14  etatp        float64
#  15  secu         float64
# dtypes: Int64(1), float64(9), int64(4), object(2)
# memory usage: 327.9+ MB

# %%
# export csv
users.to_csv("./data/users.csv", sep = ',', header = True, na_rep = 'n/a', index=False)

# %% [markdown]
# And we have the same strange column in `vehicles`:vehicles.id_vehicule.unique()

# %%
print(vehicles.id_vehicule.unique())
# Out:
# [nan '201Â\xa0764' '201Â\xa0765' ... '154Â\xa0658Â\xa0351'
#  '154Â\xa0658Â\xa0352' '154Â\xa0658Â\xa0350']

# %%
vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1914902 entries, 0 to 131047
# Data columns (total 11 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Num_Acc      int64
#  1   senc         float64
#  2   catv         int64
#  3   occutc       float64
#  4   obs          float64
#  5   obsm         float64
#  6   choc         float64
#  7   manv         float64
#  8   num_veh      object
#  9   id_vehicule  object
#  10  motor        float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 175.3+ MB

# %%
new_id_vehicles = pd.Series("id_vehicule")
new_id_vehicles.info()
new_id_vehicles.head()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1 entries, 0 to 0
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 1 non-null      object
# dtypes: object(1)
# memory usage: 136.0+ bytes
# 0    id_vehicule
# dtype: object

# %%
for i in range(0, len(vehicles)):
    value = pd.Series(pd.NA)
    if type(vehicles.iloc[i].id_vehicule) == str:
        value = pd.Series(vehicles.iloc[i].id_vehicule.replace('Â\xa0', ''))
    new_id_vehicles = new_id_vehicles._append(value)
new_id_vehicles.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[99], line 5
#       3     if type(vehicles.iloc[i].id_vehicule) == str:
#       4         value = pd.Series(vehicles.iloc[i].id_vehicule.replace('Â\xa0', ''))
# ----> 5     new_id_vehicles = new_id_vehicles._append(value)
#       6 new_id_vehicles.head(10)
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/series.py:3036, in Series._append(self, to_append, ignore_index, verify_integrity)
#    3034     msg = "to_append should be a Series or list/tuple of Series, got DataFrame"
#    3035     raise TypeError(msg)
# -> 3036 return concat(
#    3037     to_concat, ignore_index=ignore_index, verify_integrity=verify_integrity
#    3038 )
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/reshape/concat.py:372, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     369 elif copy and using_copy_on_write():
#     370     copy = False
# --> 372 op = _Concatenator(
#     373     objs,
#     374     axis=axis,
#     375     ignore_index=ignore_index,
#     376     join=join,
#     377     keys=keys,
#     378     levels=levels,
#     379     names=names,
#     380     verify_integrity=verify_integrity,
#     381     copy=copy,
#     382     sort=sort,
#     383 )
#     385 return op.get_result()
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/reshape/concat.py:563, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     560 self.verify_integrity = verify_integrity
#     561 self.copy = copy
# --> 563 self.new_axes = self._get_new_axes()
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/reshape/concat.py:633, in _Concatenator._get_new_axes(self)
#     631 def _get_new_axes(self) -> list[Index]:
#     632     ndim = self._get_result_dim()
# --> 633     return [
#     634         self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     635         for i in range(ndim)
#     636     ]
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/reshape/concat.py:634, in <listcomp>(.0)
#     631 def _get_new_axes(self) -> list[Index]:
#     632     ndim = self._get_result_dim()
#     633     return [
# --> 634         self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     635         for i in range(ndim)
#     636     ]
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/reshape/concat.py:691, in _Concatenator._get_concat_axis(self)
#     689     if self.levels is not None:
#     690         raise ValueError("levels supported only when keys is not None")
# --> 691     concat_axis = _concat_indexes(indexes)
#     692 else:
#     693     concat_axis = _make_concat_multiindex(
#     694         indexes, self.keys, self.levels, self.names
#     695     )
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/reshape/concat.py:709, in _concat_indexes(indexes)
#     708 def _concat_indexes(indexes) -> Index:
# --> 709     return indexes[0].append(indexes[1:])
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/indexes/base.py:5257, in Index.append(self, other)
#    5254 names = {obj.name for obj in to_concat}
#    5255 name = None if len(names) > 1 else self.name
# -> 5257 return self._concat(to_concat, name)
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/indexes/base.py:5267, in Index._concat(self, to_concat, name)
#    5263 to_concat_vals = [x._values for x in to_concat]
#    5265 result = concat_compat(to_concat_vals)
# -> 5267 return Index._with_infer(result, name=name)
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/indexes/base.py:671, in Index._with_infer(cls, *args, **kwargs)
#     665 @classmethod
#     666 def _with_infer(cls, *args, **kwargs):
#     667     """
#     668     Constructor that uses the 1.0.x behavior inferring numeric dtypes
#     669     for ndarray[object] inputs.
#     670     """
# --> 671     result = cls(*args, **kwargs)
#     673     if result.dtype == _dtype_obj and not result._is_multi:
#     674         # error: Argument 1 to "maybe_convert_objects" has incompatible type
#     675         # "Union[ExtensionArray, ndarray[Any, Any]]"; expected
#     676         # "ndarray[Any, Any]"
#     677         values = lib.maybe_convert_objects(result._values)  # type: ignore[arg-type]
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/indexes/base.py:479, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     469 def __new__(
#     470     cls,
#     471     data=None,
#    (...)
#     475     tupleize_cols: bool = True,
#     476 ) -> Index:
#     477     from pandas.core.indexes.range import RangeIndex
# --> 479     name = maybe_extract_name(name, data, cls)
#     481     if dtype is not None:
#     482         dtype = pandas_dtype(dtype)
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/indexes/base.py:7168, in maybe_extract_name(name, obj, cls)
#    7164 def maybe_extract_name(name, obj, cls) -> Hashable:
#    7165     """
#    7166     If no name is passed, then extract it from data, validating hashability.
#    7167     """
# -> 7168     if name is None and isinstance(obj, (Index, ABCSeries)):
#    7169         # Note we don't just check for "name" attribute since that would
#    7170         #  pick up e.g. dtype.name
#    7171         name = obj.name
#    7173     # GH#29069
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/dtypes/generic.py:42, in create_pandas_abc_type.<locals>._instancecheck(cls, inst)
#      38     return getattr(inst, attr, "_typ") in comp
#      40 # https://github.com/python/mypy/issues/1006
#      41 # error: 'classmethod' used with a non-method
# ---> 42 @classmethod  # type: ignore[misc]
#      43 def _instancecheck(cls, inst) -> bool:
#      44     return _check(inst) and not isinstance(inst, type)
#      46 @classmethod  # type: ignore[misc]
#      47 def _subclasscheck(cls, inst) -> bool:
#      48     # Raise instead of returning False
#      49     # This is consistent with default __subclasscheck__ behavior
#
# KeyboardInterrupt:

# %%
new_id_vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        1 non-null      object
#  1   id_vehicule  0 non-null      object
# dtypes: object(2)
# memory usage: 144.0+ bytes

# %% [raw]
# # new_id is still string, so let's change:
# vehicles = vehicles.astype({"id_vehicule":"int"})

# %% [raw]
# vehicles.to_csv("./data/vehicles.csv", sep = ',', header = True, na_rep = 'N/A', index=False)
