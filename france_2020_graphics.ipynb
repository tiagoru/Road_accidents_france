# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/tiago/OneDrive/Documents/GitHub/mar23cds_accidents/data/features.csv", index_col=0)

df.info()
df.head(5)
# Out:
# C:\Users\tiago\AppData\Local\Temp\ipykernel_3560\1689297041.py:1: DtypeWarning: Columns (5,11,13,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/tiago/OneDrive/Documents/GitHub/mar23cds_accidents/data/features.csv", index_col=0)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 982060 entries, 0 to 58396
# Data columns (total 16 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Num_Acc  982060 non-null  int64
#  1   an       982060 non-null  int64
#  2   mois     982060 non-null  int64
#  3   jour     982060 non-null  int64
#  4   hrmn     982060 non-null  object
#  5   lum      982060 non-null  int64
#  6   agg      982060 non-null  int64
#  7   int      982060 non-null  int64
#  8   atm      981987 non-null  float64
#  9   col      982041 non-null  float64
#  10  com      982058 non-null  object
#  11  adr      850489 non-null  object
#  12  gps      455722 non-null  object
#  13  lat      553725 non-null  object
#  14  long     553721 non-null  object
#  15  dep      982060 non-null  object
# dtypes: float64(2), int64(7), object(7)
# memory usage: 127.4+ MB
#         Num_Acc  an  mois  jour  hrmn  lum  agg  int  atm  col com  \
# 0  201400000001  14     5     7  2015    1    2    1  1.0  3.0  11
# 1  201400000002  14     5    31   430    1    2    1  1.0  6.0  11
# 2  201400000003  14     8    23  1800    1    2    9  1.0  3.0  52
# 3  201400000004  14     6    12  1700    1    2    1  1.0  1.0  25
# 4  201400000005  14     6    23   500    2    1    1  1.0  1.0  25
#
#                         adr gps  lat long  dep
# 0              route de don   M  0.0  0.0  590
# 1          106 ROUTE DE DON   M  0.0  0.0  590
# 2    75 bis rue jean jaures   M  0.0  0.0  590
# 3  rue des Sablonnieres D41   M  0.0  0.0  590
# 4                       NaN   M  0.0  0.0  590

# %%
df1 = pd.read_csv('C:/Users/tiago/OneDrive/Documents/GitHub/mar23cds_accidents/data/places.csv', index_col=0)

df1.info()
# Out:
# C:\Users\tiago\AppData\Local\Temp\ipykernel_3560\3771911701.py:1: DtypeWarning: Columns (5,11,12,13,14,15,16,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('C:/Users/tiago/OneDrive/Documents/GitHub/mar23cds_accidents/data/places.csv', index_col=0)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1069086 entries, 0 to 87025
# Data columns (total 33 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   Num_Acc  1069086 non-null  int64
#  1   an       982060 non-null   float64
#  2   mois     982060 non-null   float64
#  3   jour     982060 non-null   float64
#  4   hrmn     982060 non-null   object
#  5   lum      982060 non-null   float64
#  6   agg      982060 non-null   float64
#  7   int      982060 non-null   float64
#  8   atm      981987 non-null   float64
#  9   col      982041 non-null   float64
#  10  com      982058 non-null   object
#  11  adr      850489 non-null   object
#  12  gps      455722 non-null   object
#  13  lat      553725 non-null   object
#  14  long     553721 non-null   object
#  15  dep      982060 non-null   object
#  16  catr     87025 non-null    float64
#  17  voie     79497 non-null    float64
#  18  v1       86821 non-null    float64
#  19  v2       2136 non-null     object
#  20  circ     87026 non-null    float64
#  21  nbv      87026 non-null    float64
#  22  pr       47515 non-null    float64
#  23  pr1      47515 non-null    float64
#  24  vosp     87026 non-null    float64
#  25  prof     87026 non-null    float64
#  26  plan     87026 non-null    float64
#  27  lartpc   87026 non-null    float64
#  28  larrout  87026 non-null    float64
#  29  surf     87026 non-null    float64
#  30  infra    87026 non-null    float64
#  31  situ     87026 non-null    float64
#  32  env1     87026 non-null    float64
# dtypes: float64(24), int64(1), object(8)
# memory usage: 277.3+ MB

# %%
event_counts = df1['lum'].value_counts()

# Plot the event counts
event_counts.plot.bar()
labels = ['Full day', 'Twilight or dawn', 'Night without public lighting', 'Night with public lighting not lit', 'Night with public lighting on','misinformation']
# Add labels and title to the plot
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('light conditions ')

# Display the plot
plt.show()

# %%
event_counts = df1['col'].value_counts()

# Plot the event counts
event_counts.plot.bar()
labels = ['2 Frontal', '2 Rear', '2 by side', '3 or more chain', '3 + multiple colisions','others', 'without collision','error']
# Add labels and title to the plot
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('colision types ')

# Display the plot
plt.show()

# %%
event_counts = df['int'].value_counts()

# Plot the event counts
event_counts.plot.bar()
labels = ['Out of intersection', 'Intersection in X', 'Intersection in T', 'Intersection in Y', 'Intersection with more than 4 branches',
        ' Giratory','Place' , 'Level crossing','Other intersection',' unknow', 'error']

# Add labels and title to the plot
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('local  ')

# Display the plot
plt.show()

# %%
event_counts = df1['surf'].value_counts()

# Plot the event counts
event_counts.plot.bar()
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('Surface conditions  ')
# Out:
# Text(0.5, 1.0, 'Surface conditions  ')

# %%
event_counts = df1['an'].value_counts().sort_index()

# Plot the event counts
event_counts.plot.bar()
plt.xlabel('years')
plt.ylabel('Count')
plt.title('number of events in years  ')
# Out:
# Text(0.5, 1.0, 'number of events in years  ')

# %%
event_counts = df1['atm'].value_counts().sort_index()

# Plot the event counts
event_counts.plot.bar()

plt.xlabel('Event')
plt.ylabel('Count')
plt.title('Weather conditions')
# Out:
# Text(0.5, 1.0, 'Weather conditions')

# %%
event_counts = df1['mois'].value_counts().sort_index()

# Plot the event counts
event_counts.plot.bar()
plt.xlabel('months')
plt.ylabel('Count')
plt.title('Months accidents ')
# Out:
# Text(0.5, 1.0, 'Months accidents ')

# %%
event_counts = df1['jour'].value_counts().sort_index()

# Plot the event counts
event_counts.plot.bar()
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('accidents per day ')
# Out:
# Text(0.5, 1.0, 'accidents per day ')
