# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# df = pd.read_csv("C:/Users/tiago/OneDrive/Documents/GitHub/mar23cds_accidents/data/features.csv", index_col=0)
df = pd.read_csv("./data/features.csv", index_col=0)

df.info()
df.head(5)
# Out:
# /tmp/ipykernel_375431/4018488557.py:2: DtypeWarning: Columns (4,10,12,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./data/features.csv", index_col=0)
# <class 'pandas.core.frame.DataFrame'>
# Index: 1121571 entries, 201400000001 to 201300058397
# Data columns (total 15 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   an      1121571 non-null  int64
#  1   mois    1121571 non-null  int64
#  2   jour    1121571 non-null  int64
#  3   hrmn    1121571 non-null  object
#  4   lum     1121571 non-null  int64
#  5   agg     1121571 non-null  int64
#  6   int     1121571 non-null  int64
#  7   atm     1121498 non-null  float64
#  8   col     1121552 non-null  float64
#  9   com     1121569 non-null  object
#  10  adr     978295 non-null   object
#  11  gps     480052 non-null   object
#  12  lat     634503 non-null   float64
#  13  long    631290 non-null   float64
#  14  dep     1121571 non-null  object
# dtypes: float64(4), int64(6), object(5)
# memory usage: 136.9+ MB
#                 an  mois  jour  hrmn  lum  agg  int  atm  col com  \
# Num_Acc
# 201400000001  2014     5     7  2015    1    2    1  1.0  3.0  11
# 201400000002  2014     5    31   430    1    2    1  1.0  6.0  11
# 201400000003  2014     8    23  1800    1    2    9  1.0  3.0  52
# 201400000004  2014     6    12  1700    1    2    1  1.0  1.0  25
# 201400000005  2014     6    23   500    2    1    1  1.0  1.0  25
#
#                                    adr gps  lat  long  dep
# Num_Acc
# 201400000001              route de don   M  0.0   0.0  590
# 201400000002          106 ROUTE DE DON   M  0.0   0.0  590
# 201400000003    75 bis rue jean jaures   M  0.0   0.0  590
# 201400000004  rue des Sablonnieres D41   M  0.0   0.0  590
# 201400000005                       NaN   M  0.0   0.0  590

# %%
# df1 = pd.read_csv('C:/Users/tiago/OneDrive/Documents/GitHub/mar23cds_accidents/data/places.csv', index_col=0)
df1 = pd.read_csv('./data/places.csv', index_col=0)
df1.info()
df1.head(5)
# Out:
# /tmp/ipykernel_375431/2349406459.py:2: DtypeWarning: Columns (2,9,10,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('./data/places.csv', index_col=0)
# <class 'pandas.core.frame.DataFrame'>
# Index: 1121571 entries, 201900000001 to 200500087954
# Data columns (total 18 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   catr     1121570 non-null  float64
#  1   voie     1014391 non-null  object
#  2   v1       485747 non-null   float64
#  3   v2       51369 non-null    object
#  4   circ     1119997 non-null  float64
#  5   nbv      1118840 non-null  float64
#  6   vosp     1118810 non-null  float64
#  7   prof     1119622 non-null  float64
#  8   pr       646087 non-null   object
#  9   pr1      644268 non-null   object
#  10  plan     1119290 non-null  float64
#  11  lartpc   902739 non-null   object
#  12  larrout  1008730 non-null  object
#  13  surf     1119647 non-null  float64
#  14  infra    1116163 non-null  float64
#  15  situ     1116601 non-null  float64
#  16  vma      163102 non-null   float64
#  17  env1     953029 non-null   float64
# dtypes: float64(12), object(6)
# memory usage: 162.6+ MB
#               catr voie   v1   v2  circ   nbv  vosp  prof  pr  pr1  plan  \
# Num_Acc
# 201900000001   1.0    3  0.0  NaN   3.0  10.0   0.0   1.0   6  900   2.0
# 201900000002   1.0    1  0.0  NaN   1.0   2.0   0.0   4.0   3  845   2.0
# 201900000003   1.0   86  0.0  NaN   3.0   8.0   0.0   1.0  10  500   3.0
# 201900000004   1.0    4  0.0  NaN   3.0   5.0   0.0   1.0   2  299   1.0
# 201900000005   1.0   86  0.0  INT   1.0   3.0   0.0   1.0  41    0   3.0
#
#              lartpc larrout  surf  infra  situ   vma  env1
# Num_Acc
# 201900000001    NaN     NaN   1.0    2.0   1.0  70.0   NaN
# 201900000002    NaN     NaN   1.0    0.0   1.0  70.0   NaN
# 201900000003    NaN     NaN   1.0    0.0   1.0  90.0   NaN
# 201900000004    NaN     NaN   1.0    0.0   1.0  90.0   NaN
# 201900000005    NaN     NaN   1.0    2.0   1.0  90.0   NaN

# %%
# df2 = pd.read_csv('C:/Users/tiago/OneDrive/Documents/GitHub/mar23cds_accidents/data/registered_vehicles.csv', index_col=0)
df2 = pd.read_csv('./data/registered_vehicles.csv', index_col=0)
df2.info()
df2.head(5)
# Out:
# /tmp/ipykernel_375431/1103164871.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('./data/registered_vehicles.csv', index_col=0)
# <class 'pandas.core.frame.DataFrame'>
# Index: 1290207 entries, 900493.0 to 66554982.0
# Data columns (total 8 columns):
#  #   Column                              Non-Null Count    Dtype
# ---  ------                              --------------    -----
#  0   Lettre Conventionnelle Véhicule     1290206 non-null  object
#  1   Année                               1290207 non-null  int64
#  2   Lieu Admin Actuel - Territoire Nom  1290207 non-null  object
#  3   Type Accident - Libellé             1078193 non-null  object
#  4   CNIT                                845998 non-null   object
#  5   Catégorie véhicule                  1290207 non-null  object
#  6   Age véhicule                        1181107 non-null  float64
#  7   Type Accident - Libellé (old)       212014 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 88.6+ MB
#             Lettre Conventionnelle Véhicule  Année  \
# Id_accident
# 900493.0                                  A   2014
# 900493.0                                  B   2014
# 900494.0                                  A   2014
# 900495.0                                  A   2014
# 900496.0                                  A   2014
#
#             Lieu Admin Actuel - Territoire Nom    Type Accident - Libellé  \
# Id_accident
# 900493.0                                   DOM             Accident Léger
# 900493.0                                   DOM             Accident Léger
# 900494.0                                   DOM  Accident grave non mortel
# 900495.0                                   DOM  Accident grave non mortel
# 900496.0                                   DOM  Accident grave non mortel
#
#                         CNIT Catégorie véhicule  Age véhicule  \
# Id_accident
# 900493.0     VF7MFDJYF651296                 VT           NaN
# 900493.0                 NaN              Cyclo           NaN
# 900494.0                 NaN                 VT           4.0
# 900495.0        LMP21C10N026              Cyclo           7.0
# 900496.0        LSY91C10U174              Cyclo           6.0
#
#             Type Accident - Libellé (old)
# Id_accident
# 900493.0                              NaN
# 900493.0                              NaN
# 900494.0                              NaN
# 900495.0                              NaN
# 900496.0                              NaN

# %%
# df3 = pd.read_csv('C:/Users/tiago/OneDrive/Documents/GitHub/mar23cds_accidents/data/users.csv', index_col=0)
df3 = pd.read_csv('./data/users.csv', index_col=0)

df3.info()
df3.head()
# Out:
# /tmp/ipykernel_375431/1727014592.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv('./data/users.csv', index_col=0)
# <class 'pandas.core.frame.DataFrame'>
# Index: 2509620 entries, 201900000001 to 200500087954
# Data columns (total 15 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id_vehicule  float64
#  1   num_veh      object
#  2   place        float64
#  3   catu         int64
#  4   grav         int64
#  5   sexe         int64
#  6   an_nais      float64
#  7   trajet       float64
#  8   secu1        float64
#  9   secu2        float64
#  10  secu3        float64
#  11  locp         float64
#  12  actp         object
#  13  etatp        float64
#  14  secu         float64
# dtypes: float64(10), int64(3), object(2)
# memory usage: 306.4+ MB
#               id_vehicule num_veh  place  catu  grav  sexe  an_nais  trajet  \
# Num_Acc
# 201900000001  138306524.0     B01    2.0     2     4     2   2002.0     0.0
# 201900000001  138306524.0     B01    1.0     1     4     2   1993.0     5.0
# 201900000001  138306525.0     A01    1.0     1     1     1   1959.0     0.0
# 201900000002  138306523.0     A01    1.0     1     4     2   1994.0     0.0
# 201900000003  138306520.0     A01    1.0     1     1     1   1996.0     0.0
#
#               secu1  secu2  secu3  locp actp  etatp  secu
# Num_Acc
# 201900000001    1.0    0.0   -1.0  -1.0   -1   -1.0   NaN
# 201900000001    1.0    0.0   -1.0  -1.0   -1   -1.0   NaN
# 201900000001    1.0    0.0   -1.0  -1.0   -1   -1.0   NaN
# 201900000002    1.0    0.0   -1.0  -1.0   -1   -1.0   NaN
# 201900000003    1.0    0.0   -1.0  -1.0    0   -1.0   NaN

# %%
# df4 = pd.read_csv('C:/Users/tiago/OneDrive/Documents/GitHub/mar23cds_accidents/data/vehicles.csv', index_col=0)
df4 = pd.read_csv('./data/vehicles.csv', index_col=0)
df4.info()
df4.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1914902 entries, 200500000001 to 200800077569
# Data columns (total 10 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   senc         float64
#  1   catv         int64
#  2   occutc       float64
#  3   obs          float64
#  4   obsm         float64
#  5   choc         float64
#  6   manv         float64
#  7   num_veh      object
#  8   id_vehicule  float64
#  9   motor        float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 160.7+ MB
#               senc  catv  occutc  obs  obsm  choc  manv num_veh  id_vehicule  \
# Num_Acc
# 200500000001   0.0     7     0.0  0.0   2.0   1.0   1.0     A01          NaN
# 200500000001   0.0     7     0.0  0.0   2.0   8.0  10.0     B02          NaN
# 200500000002   0.0     7     0.0  0.0   2.0   7.0  16.0     A01          NaN
# 200500000002   0.0     2     0.0  0.0   2.0   1.0   1.0     B02          NaN
# 200500000003   0.0     2     0.0  0.0   2.0   1.0   1.0     A01          NaN
#
#               motor
# Num_Acc
# 200500000001    NaN
# 200500000001    NaN
# 200500000002    NaN
# 200500000002    NaN
# 200500000003    NaN

# %%
# merge files
merged_df = pd.merge(df, df1, on='Num_Acc',suffixes=('_df', '_df1'))
merged_df = pd.merge(merged_df, df3, on='Num_Acc',suffixes=('_merged_df', '_df3'))
merged_df = pd.merge(merged_df, df4, on='Num_Acc',suffixes=('_merged_df', '_df4'))

# %%
# merged_df.to_csv("./data/merged_tables.csv", sep = ',', header = True, na_rep = 'n/a', index=True)

# %%
merged_df =pd.read_csv('./data/merged_tables.csv', index_col=0)
merged_df.head(5)
merged_df.info()
# Out:
# /tmp/ipykernel_375431/730529533.py:1: DtypeWarning: Columns (4,10,12,15,17,19,24,25,27,28,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_df =pd.read_csv('./data/merged_tables.csv', index_col=0)
# <class 'pandas.core.frame.DataFrame'>
# Index: 4763230 entries, 201400000001 to 201300058397
# Data columns (total 58 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   an                     int64
#  1   mois                   int64
#  2   jour                   int64
#  3   hrmn                   object
#  4   lum                    int64
#  5   agg                    int64
#  6   int                    int64
#  7   atm                    float64
#  8   col                    float64
#  9   com                    object
#  10  adr                    object
#  11  gps                    object
#  12  lat                    float64
#  13  long                   float64
#  14  dep                    object
#  15  catr                   float64
#  16  voie                   object
#  17  v1                     float64
#  18  v2                     object
#  19  circ                   float64
#  20  nbv                    float64
#  21  vosp                   float64
#  22  prof                   float64
#  23  pr                     object
#  24  pr1                    object
#  25  plan                   float64
#  26  lartpc                 object
#  27  larrout                object
#  28  surf                   float64
#  29  infra                  float64
#  30  situ                   float64
#  31  vma                    float64
#  32  env1                   float64
#  33  id_vehicule_merged_df  float64
#  34  num_veh_merged_df      object
#  35  place                  float64
#  36  catu                   int64
#  37  grav                   int64
#  38  sexe                   int64
#  39  an_nais                float64
#  40  trajet                 float64
#  41  secu1                  float64
#  42  secu2                  float64
#  43  secu3                  float64
#  44  locp                   float64
#  45  actp                   object
#  46  etatp                  float64
#  47  secu                   float64
#  48  senc                   float64
#  49  catv                   int64
#  50  occutc                 float64
#  51  obs                    float64
#  52  obsm                   float64
#  53  choc                   float64
#  54  manv                   float64
#  55  num_veh_df4            object
#  56  id_vehicule_df4        float64
#  57  motor                  float64
# dtypes: float64(34), int64(10), object(14)
# memory usage: 2.1+ GB

# %%
duplicates = merged_df.duplicated()

# Count the number of duplicates
num_duplicates = duplicates.sum()

# Print the number of duplicates
print("Number of duplicates:", num_duplicates)
# Out:
# Number of duplicates: 4664

# %%
#agg
event_counts = merged_df['agg'].value_counts()

# Plot the event counts
plt.figure(figsize=(10, 12))
plt.subplot(1, 2, 1)
event_counts.plot.bar()
labels = ['Out of agglomeration', 'In built-up areas']
# Add labels and title to the plot
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('agglomeration')

event_percentages = (event_counts / event_counts.sum()) * 100
plt.subplot(1, 2, 2)
event_percentages.plot.bar()
labels = ['Out of agglomeration', 'In built-up areas']
# Add labels and title to the plot
plt.xticks(range(len(event_percentages)), labels)
plt.xlabel('Events')
plt.ylabel('Count %')
plt.title('Agglomeration')
# Display the plot
plt.show()

# %%
# After update, most duplicate variables disappeared
# event_counts = merged_df['lum_df'].value_counts()
event_counts = merged_df['lum'].value_counts()

# Plot the event counts
plt.subplot(1, 2, 1)
event_counts.plot.bar()
labels = ['Full day', 'Twilight or dawn', 'Night without public lighting', 'Night with public lighting not lit', 'Night with public lighting on','misinformation']
# Add labels and title to the plot
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('light conditions ')

event_percentages = (event_counts / event_counts.sum()) * 100
plt.subplot(1, 2, 2)
event_percentages.plot.bar()
# Add labels and title to the plot
plt.xticks(range(len(event_percentages)), labels)
plt.xlabel('Events')
plt.ylabel('Count %')
plt.title('light conditions ')

# Display the plot
plt.show()

# %%
# After update, most duplicate variables disappeared
# event_counts = merged_df['int_df'].value_counts()
event_counts = merged_df['int'].value_counts()

# Plot the event counts
plt.subplot(1, 2, 1)
event_counts.plot.bar()
labels = ['Out of intersection', 'Intersection in X', 'Intersection in T', 'Intersection in Y', 'Intersection with more than 4 branches',
        ' Giratory','Place' , 'Level crossing','Other intersection',' unknow', 'error']

# Add labels and title to the plot

plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('local  ')

event_percentages = (event_counts / event_counts.sum()) * 100
plt.subplot(1, 2, 2)
event_percentages.plot.bar()
# Add labels and title to the plot
plt.xticks(range(len(event_percentages)), labels)
plt.xlabel('Events')
plt.ylabel('Count %')
plt.title('local')


# Display the plot
plt.show()

# %%
event_counts = merged_df['atm'].value_counts().sort_index()
labels = ['Normal', 'Light rain', 'Heavy Rain', 'Snow hail', 'Fog - Smoke','Strong wind- storm','Dazzling weather' , 'Cloudy weather',
          'Other ', 'error']
# Plot the event counts
plt.subplot(1, 2, 1)
event_counts.plot.bar()
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('Weather conditions');

event_percentages = (event_counts / event_counts.sum()) * 100
plt.subplot(1, 2, 2)
event_percentages.plot.bar()
# Add labels and title to the plot
plt.xticks(range(len(event_percentages)), labels)
plt.xlabel('Events')
plt.ylabel('Count %')
plt.title('Weather conditions')


# Display the plot
plt.show()

# %%
# After update, most duplicate variables disappeared
# event_counts = merged_df['col_df'].value_counts()
event_counts = merged_df['col'].value_counts()

# Plot the event counts
plt.subplot(1, 2, 1)
event_counts.plot.bar()

labels = ['2 Frontal', '2 Rear', '2 by side', '3 or more chain', '3 + multiple colisions','others', 'without collision','error']
# Add labels and title to the plot
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('colision conditions ')

event_percentages = (event_counts / event_counts.sum()) * 100
plt.subplot(1, 2, 2)
event_percentages.plot.bar()
# Add labels and title to the plot
plt.xticks(range(len(event_percentages)), labels)
plt.xlabel('Events')
plt.ylabel('Count %')
plt.title('Colision conditions')


# Display the plot
plt.show()

# %%
event_counts = merged_df['gps'].value_counts()

# Plot the event counts
plt.subplot(1, 2, 1)
event_counts.plot.bar()
#labels = ['Métropole', 'antilles', 'Guyane', 'Reunion', 'Mayote']

# Add labels and title to the plot
plt.xticks(range(len(event_counts)))
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('GPS')
event_percentages = (event_counts / event_counts.sum()) * 100
plt.subplot(1, 2, 2)
event_percentages.plot.bar()
# Add labels and title to the plot
plt.xticks(range(len(event_percentages)))
plt.xlabel('Events')
plt.ylabel('Count %')
plt.title('GPS')


# Display the plot
plt.show()

# %%
# event_counts = merged_df['col_df'].value_counts()
event_counts = merged_df['catr'].value_counts()

# Plot the event counts
plt.subplot(1, 2, 1)
event_counts.plot.bar()

labels = ['Highway', 'National road', 'Departamental road', 'Comunal way', 'OFF public network','Parking lot ', 'Public','other']
# Add labels and title to the plot
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('Type of Road')

event_percentages = (event_counts / event_counts.sum()) * 100
plt.subplot(1, 2, 2)
event_percentages.plot.bar()
# Add labels and title to the plot
plt.xticks(range(len(event_percentages)), labels)
plt.xlabel('Events')
plt.ylabel('Count %')
plt.title('Type of Road')


# Display the plot
plt.show()

# %%
# event_counts = merged_df['col_df'].value_counts()
event_counts = merged_df['circ'].value_counts()

# Plot the event counts
plt.subplot(1, 2, 1)
event_counts.plot.bar()

labels = ['One way', 'Bidirectional', 'separeted carriageways', 'with variable assigment channels', 'error','error 2']
# Add labels and title to the plot
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('Traffic direction ')

event_percentages = (event_counts / event_counts.sum()) * 100
plt.subplot(1, 2, 2)
event_percentages.plot.bar()
# Add labels and title to the plot
plt.xticks(range(len(event_percentages)), labels)
plt.xlabel('Events')
plt.ylabel('Count %')
plt.title('Traffic direction')


# Display the plot
plt.show()

# %%
# event_counts = merged_df['col_df'].value_counts()
event_counts = merged_df['vosp'].value_counts()

# Plot the event counts
plt.subplot(1, 2, 1)
event_counts.plot.bar()

labels = ['Bike Path', 'Cycle Bank', 'Reserved channel ','erro1', 'error2']
# Add labels and title to the plot
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('VOSP')

event_percentages = (event_counts / event_counts.sum()) * 100
plt.subplot(1, 2, 2)
event_percentages.plot.bar()
# Add labels and title to the plot
plt.xticks(range(len(event_percentages)), labels)
plt.xlabel('Events')
plt.ylabel('Count %')
plt.title('VOSP')


# Display the plot
plt.show()

# %%
# event_counts = merged_df['col_df'].value_counts()
event_counts = merged_df['prof'].value_counts()

# Plot the event counts
plt.subplot(1, 2, 1)
event_counts.plot.bar()

labels = ['Dish', 'Slope', 'Hilltop ','Hillbotton', 'error1','error2']
# Add labels and title to the plot
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('PROF')

event_percentages = (event_counts / event_counts.sum()) * 100
plt.subplot(1, 2, 2)
event_percentages.plot.bar()
# Add labels and title to the plot
plt.xticks(range(len(event_percentages)), labels)
plt.xlabel('Events')
plt.ylabel('Count %')
plt.title('PROF')


# Display the plot
plt.show()

# %%
# event_counts = merged_df['col_df'].value_counts()
event_counts = merged_df['surf'].value_counts()

# Plot the event counts
plt.subplot(1, 2, 1)
event_counts.plot.bar()

labels = ['Normal', 'Wet', 'puddles', 'flooded', 'snow','mud','icy', 'fat-oil', 'Other ', 'error1','error2']
# Add labels and title to the plot
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('Surface condition')

event_percentages = (event_counts / event_counts.sum()) * 100
plt.subplot(1, 2, 2)
event_percentages.plot.bar()
# Add labels and title to the plot
plt.xticks(range(len(event_percentages)), labels)
plt.xlabel('Events')
plt.ylabel('Count %')
plt.title('Surface condition')


# Display the plot
plt.show()

# %%
# event_counts = merged_df['col_df'].value_counts()
event_counts = merged_df['infra'].value_counts()

# Plot the event counts
plt.subplot(1, 2, 1)
event_counts.plot.bar()

labels = ['Underground _tunnel', 'Bridge', 'Exchanger or connectionbrace', 'Railway', 'carrefour arranged','Pedestrian','toll zone', 'error1','error2', 'error3','error4']
# Add labels and title to the plot
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('infrastructure')

event_percentages = (event_counts / event_counts.sum()) * 100
plt.subplot(1, 2, 2)
event_percentages.plot.bar()
# Add labels and title to the plot
plt.xticks(range(len(event_percentages)), labels)
plt.xlabel('Events')
plt.ylabel('Count %')
plt.title('infrastructure')


# Display the plot
plt.show()

# %%
# event_counts = merged_df['col_df'].value_counts()
event_counts = merged_df['situ'].value_counts()

# Plot the event counts
plt.subplot(1, 2, 1)
event_counts.plot.bar()

labels = ['on the road', 'on emergency stop band', 'on the verge', 'on the sidewalk', 'on bike path', 'error1','error2', 'error3','error4']
# Add labels and title to the plot
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('Place of the accident ')

event_percentages = (event_counts / event_counts.sum()) * 100
plt.subplot(1, 2, 2)
event_percentages.plot.bar()
# Add labels and title to the plot
plt.xticks(range(len(event_percentages)), labels)
plt.xlabel('Events')
plt.ylabel('Count %')
plt.title('Place of the accident')


# Display the plot
plt.show()

# %%
# event_counts = merged_df['col_df'].value_counts()
event_counts = merged_df['senc'].value_counts()

# Plot the event counts
plt.subplot(1, 2, 1)
event_counts.plot.bar()

labels = ['Not Specified', 'Unknown', 'PK or PR ascending postal adress', 'PK or PR descending postal adress', 'Absence or mark']#, 'error1','error2', 'error3','error4']
# Add labels and title to the plot
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('SENC ')

event_percentages = (event_counts / event_counts.sum()) * 100
plt.subplot(1, 2, 2)
event_percentages.plot.bar()
# Add labels and title to the plot
plt.xticks(range(len(event_percentages)), labels)
plt.xlabel('Events')
plt.ylabel('Count %')
plt.title('SENC')


# Display the plot
plt.show()

# %%
# event_counts = merged_df['col_df'].value_counts()
event_counts = merged_df['catv'].value_counts()

# Plot the event counts
plt.subplot(1, 2, 1)
event_counts.plot.bar()

labels = ['Indeterminable', 'Bicycle', 'Moped', 'Tri or quad cyle', 'Scooter*','Motorcycle*','sidecar*','LV only','LV + Caravan', 'car + Trailer','LCV only'
          'LCV(10) + trailer', 'LCV(10) + trailer2','Truck only 3.5T <PTCA <= 7.5T ', 'Truck only > 7.5T  ','Truck > 3.5T + trailer  ', '' Truck tractor only  ]
# Add labels and title to the plot
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('Vehicule categorie ')

event_percentages = (event_counts / event_counts.sum()) * 100
plt.subplot(1, 2, 2)
event_percentages.plot.bar()
# Add labels and title to the plot
plt.xticks(range(len(event_percentages)), labels)
plt.xlabel('Events')
plt.ylabel('Count %')
plt.title('Vehicule categorie')


# Display the plot
plt.show()
# Out:
#   Cell In[25], line 9
#     'LCV(10) + trailer', 'LCV(10) + trailer2','Truck only 3.5T <PTCA <= 7.5T ', 'Truck only > 7.5T  ','Truck > 3.5T + trailer  ', '' Truck tractor only  ]
#                                                                                                                                   ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# After update, most duplicate variables disappeared
# event_counts = merged_df['int_df'].value_counts()
event_counts = merged_df['int'].value_counts()

# Plot the event counts
event_counts.plot.bar()
labels = labels = ['Normal', 'Wet', 'puddles', 'flooded', 'snow','mud','icy', 'fat-oil', 'Other ', 'error']

# Add labels and title to the plot
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('local  ')

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 10
#       7 labels = labels = ['Normal', 'Wet', 'puddles', 'flooded', 'snow','mud','icy', 'fat-oil', 'Other ', 'error']
#       9 # Add labels and title to the plot
# ---> 10 plt.xticks(range(len(event_counts)), labels)
#      11 plt.xlabel('Event')
#      12 plt.ylabel('Count')
#
# File ~/miniforge3/lib/python3.10/site-packages/matplotlib/pyplot.py:1893, in xticks(ticks, labels, minor, **kwargs)
#    1891         l._internal_update(kwargs)
#    1892 else:
# -> 1893     labels = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    1895 return locs, labels
#
# File ~/miniforge3/lib/python3.10/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.10/site-packages/matplotlib/axis.py:1969, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    1965 if isinstance(locator, mticker.FixedLocator):
#    1966     # Passing [] as a list of labels is often used as a way to
#    1967     # remove all tick labels, so only error for > 0 labels
#    1968     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 1969         raise ValueError(
#    1970             "The number of FixedLocator locations"
#    1971             f" ({len(locator.locs)}), usually from a call to"
#    1972             " set_ticks, does not match"
#    1973             f" the number of labels ({len(labels)}).")
#    1974     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    1975     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (11), usually from a call to set_ticks, does not match the number of labels (10).

# %%
event_counts = merged_df['surf'].value_counts()
labels = ['Normal', 'Wet', 'puddles', 'flooded', 'snow','mud','icy', 'fat-oil', 'Other ', 'error']
# Plot the event counts
event_counts.plot.bar()
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('Surface conditions')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 5
#       3 # Plot the event counts
#       4 event_counts.plot.bar()
# ----> 5 plt.xticks(range(len(event_counts)), labels)
#       6 plt.xlabel('Event')
#       7 plt.ylabel('Count')
#
# File ~/miniforge3/lib/python3.10/site-packages/matplotlib/pyplot.py:1893, in xticks(ticks, labels, minor, **kwargs)
#    1891         l._internal_update(kwargs)
#    1892 else:
# -> 1893     labels = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    1895 return locs, labels
#
# File ~/miniforge3/lib/python3.10/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.10/site-packages/matplotlib/axis.py:1969, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    1965 if isinstance(locator, mticker.FixedLocator):
#    1966     # Passing [] as a list of labels is often used as a way to
#    1967     # remove all tick labels, so only error for > 0 labels
#    1968     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 1969         raise ValueError(
#    1970             "The number of FixedLocator locations"
#    1971             f" ({len(locator.locs)}), usually from a call to"
#    1972             " set_ticks, does not match"
#    1973             f" the number of labels ({len(labels)}).")
#    1974     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    1975     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (11), usually from a call to set_ticks, does not match the number of labels (10).

# %%
event_counts = merged_df['an'].value_counts().sort_index()

# Plot the event counts
event_counts.plot.bar()
plt.xlabel('year')
plt.ylabel('Count')
plt.title('number of events per year');

# %%
event_counts = merged_df['atm'].value_counts().sort_index()
labels = ['Normal', 'Light rain', 'Heavy Rain', 'Snow hail', 'Fog - Smoke','Strong wind- storm','Dazzling weather' , 'Cloudy weather',
          'Other ', 'error']
# Plot the event counts
event_counts.plot.bar()
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('Weather conditions');

# %%
event_counts = df['mois'].value_counts().sort_index()

# Plot the event counts
event_counts.plot.bar()
plt.xlabel('month')
plt.ylabel('Count')
plt.title('Distribution of accidents per months');

# %%
event_counts = df['jour'].value_counts().sort_index()

# Plot the event counts
event_counts.plot.bar()
plt.xlabel('day')
plt.ylabel('Count')
plt.title('accidents per day');

# %%
event_counts = merged_df['sexe'].value_counts()

# Plot the event counts
event_counts.plot.bar()
plt.xlabel(' 1- Male 2- Female')
plt.ylabel('Count')
plt.title('Number of accidents per gender');

# %%
event_counts = merged_df['grav'].value_counts()

# Plot the event counts
event_counts.plot.bar()
labels = ['Unscathed', 'Killed', 'Hospitalized wounded', 'Ligh injury']
# Add labels and title to the plot
plt.xticks(range(len(event_counts)), labels)
plt.xlabel('Event')
plt.ylabel('Count')
plt.title('light conditions ')

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 7
#       5 labels = ['Unscathed', 'Killed', 'Hospitalized wounded', 'Ligh injury']
#       6 # Add labels and title to the plot
# ----> 7 plt.xticks(range(len(event_counts)), labels)
#       8 plt.xlabel('Event')
#       9 plt.ylabel('Count')
#
# File ~/miniforge3/lib/python3.10/site-packages/matplotlib/pyplot.py:1893, in xticks(ticks, labels, minor, **kwargs)
#    1891         l._internal_update(kwargs)
#    1892 else:
# -> 1893     labels = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    1895 return locs, labels
#
# File ~/miniforge3/lib/python3.10/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.10/site-packages/matplotlib/axis.py:1969, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    1965 if isinstance(locator, mticker.FixedLocator):
#    1966     # Passing [] as a list of labels is often used as a way to
#    1967     # remove all tick labels, so only error for > 0 labels
#    1968     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 1969         raise ValueError(
#    1970             "The number of FixedLocator locations"
#    1971             f" ({len(locator.locs)}), usually from a call to"
#    1972             " set_ticks, does not match"
#    1973             f" the number of labels ({len(labels)}).")
#    1974     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    1975     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (5), usually from a call to set_ticks, does not match the number of labels (4).

# %% [raw]
# # I copiedthis part to another notebook
# columns = [ 'lum', 'col','atm','surf','int','catr','circ','vosp', 'prof', 'plan', 'infra','situ','catv','catu', 'grav',
#           'trajet','secu', 'locp', 'actp']  # Modify this list with your desired columns
#
# # Create a correlation matrix
# correlation_matrix = merged_df[columns].corr()
# plt.figure(figsize=(14, 14))
# # Generate the heatmap
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
#
# # Add a title
# plt.title('Correlation Heatmap')
#
# # Display the plot
# plt.show()
